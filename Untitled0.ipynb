# %%
import string
with open("pride and prejudice.txt") as file: 
  text.read()
text=text.lower()

for remove_punctuation in string.punctuation():
  text=text.replace(remove_punctuation, " ")
words=text.split()
word_frequency={}
for word in words:
  if word not in word_frequency.keys():
    word_frequency[]=1
  else:
    word_frequency=word_frequency[]+1
file=open("choji.csv", "w")
file.write("word, frequency\n")
for word in word_frequency.items():
  file.write("word, frequency\n")
# Out:
#   File "<ipython-input-4-eb2e926aa338>", line 11
#     if word not in word_frequency
#                                  ^
# SyntaxError: invalid syntax

# %%
""

# %% [markdown]
# Steps for processing pride and prejudice data
# 1. open the text file on python
# 2. clean the data
# 3. inmport string & remove punctuations
# 4. split the data
# 5. Create dictionary & populate
# 6. Create a CSV file and populate
